# %%
print('hi')
# Out:
# hi

# %%
pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=vSzEgGeYSBg&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=1
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 01_Jupiter_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=egRQ2z9g9C0&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=2
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 01_Jupiter_2_vc.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=R8mHsfURia0&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=3
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 02_Sonata_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=xPUsFnS6qFc&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=4
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 02_Sonata_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=7FKrzOLFWQw&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=5
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 03_Dance_1_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=vyrDeuZRh0s&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=6
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 03_Dance_2_cl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=_0VXOsjslos&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=7
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 04_Allegro_1_fl.mp4'

# %%
import os

# 디렉토리 경로 설정
directory_path = '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets'  # 디렉토리 경로를 실제 경로로 변경해주세요.

# 디렉토리 내의 모든 파일 목록 가져오기
file_list = os.listdir(directory_path)

# 파일 이름 변경
for filename in file_list:
    # 새 파일 이름 생성
    new_filename = filename.replace("--", "_").replace(" ", "_").replace("URMP Dataset Annotation", "URMP_Dataset_Annotation").replace(".mp4", ".mp3")

    # 파일 이름 변경
    old_path = os.path.join(directory_path, filename)
    new_path = os.path.join(directory_path, new_filename)
    os.rename(old_path, new_path)

print("모든 파일 이름을 변경했습니다.")

# %%
import os

# 디렉토리 경로 설정
directory_path = '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets'  # 디렉토리 경로를 실제 경로로 변경해주세요.

# 디렉토리 내의 모든 파일 목록 가져오기
file_list = os.listdir(directory_path)

# 파일 이름 변경
for filename in file_list:
    # 새 파일 이름 생성
    new_filename = filename.replace("--", "_").replace(" ", "_").replace("URMP Dataset Annotation", "URMP_Dataset_Annotation").replace(".mp4", ".mp3")

    # 파일 이름 변경
    old_path = os.path.join(directory_path, filename)
    new_path = os.path.join(directory_path, new_filename)
    os.rename(old_path, new_path)

print("모든 파일 이름을 변경했습니다.")

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=CeCKxtuMj5s&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=8
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 04_Allegro_2_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=cceNLNNKyBE&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=9
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 05_Entertainer_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=NWlczTecQ_o&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=10
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 05_Entertainer_2_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=32mD-xe2Wq0&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=11
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 06_Entertainer_1_sax.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=rBTxrDEavf8&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=12
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 06_Entertainer_2_sax.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=TN0vVtru6do&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=13
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 07_GString_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=dJ28sTr68Qk&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=14
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 07_GString_2_tbn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=6jFB1SUSN_8&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=15
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 08_Spring_1_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=zs0TaCRfLZk&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=16
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 08_Spring_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=LfDmWa5zEWA&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=17
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 09_Jesus_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=mSibE-Q1oFo&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=18
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 09_Jesus_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=lOzSJInbb-8&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=19
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 10_March_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=lgS6wOJ9Dn0&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=20
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 10_March_2_sax.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=lmSUv3z0wqE&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=21
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 11_Maria_1_ob.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=-ip5TQBAQs4&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=22
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 11_Maria_2_vc.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=YWW_iZfx7ZE&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=23
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 12_Spring_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=BZ4-lRxfSl0&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=24
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 12_Spring_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=fcr1n7xbcbA&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=25
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 12_Spring_3_vc.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=lVgOEvxfysQ&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=26
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 13_Hark_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=Oa6f9dQBlDU&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=27
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 13_Hark_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=L_KBjA8JQi8&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=28
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 13_Hark_3_va.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=s1qAb3oJ43w&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=29
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 14_Waltz_1_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=xlxETUsYmIk&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=30
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 14_Waltz_2_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=nlRMeERiJ7w&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=31
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 14_Waltz_3_cl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=B7Nl_n7Ev24&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=32
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 15_Surprise_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=3-ELzkUaOQU&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=33
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 15_Surprise_2_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=0j0UD0FuKdI&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=34
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 15_Surprise_3_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=szolOqrGtyo&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=35
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 16_Surprise_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=Q9Rmaich_V8&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=36
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 16_Surprise_2_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=JT5XkrGvg20&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=37
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 16_Surprise_3_sax.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=9HYWc8RpLLA&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=38
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 17_Nocturne_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 33_Elise_3_hn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=iqzC-Zu3AaM&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=98
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 33_Elise_4_tbn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=9hsFavD6BvU&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=99
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 34_Fugue_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=ta5qe1nahoc&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=100
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 34_Fugue_2_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=2ciEk59XczY&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=101
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 34_Fugue_3_hn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=HhRWMeKEvl0&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=102
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 34_Fugue_4_tbn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=hLe7Cdn2MXk&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=103
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 35_Rondeau_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=fJ7ZgWaPsVQ&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=104
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 35_Rondeau_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=4jpjKAGPOu4&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=105
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 35_Rondeau_3_va.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=smFS_M6lyg4&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=107
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 36_Rondeau_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=_3AKbYT_pJ8&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=106
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 35_Rondeau_4_db.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=JN9JwgNZbto&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=108
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 36_Rondeau_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=eWBtVHsAKzc&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=110
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 36_Rondeau_4_vc.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=zvy5acHKdoU&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=109
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 36_Rondeau_3_va.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=7QHEXOkQIEA&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=111
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 37_Rondeau_1_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=7lyRK7YcveE&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=112
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 37_Rondeau_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=gNLdDSNkJBY&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=113
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 37_Rondeau_3_va.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=cJqnF0MvSME&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=114
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 37_Rondeau_4_cl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=8tIM4KdZmh8&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=115
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 38_Jerusalem_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=r_uXsHsTQnc&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=116
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 38_Jerusalem_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=9gV4TYkesfA&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=117
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 38_Jerusalem_3_va.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=ZIpsr-Lez0c&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=118
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 38_Jerusalem_4_vc.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=DV_4cpc7Q8A&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=119
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 38_Jerusalem_5_db.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=lIf3pVqt95E&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=120
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 39_Jerusalem_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=Gmq4ewvXlkI&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=121
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 39_Jerusalem_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=dOjelOAuGYw&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=122
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 39_Jerusalem_3_va.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=eYw3DRevKIY&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=123
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 39_Jerusalem_4_sax.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=IdbehteH8jM&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=124
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 39_Jerusalem_5_db.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=utq91SdflCI&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=125
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 40_Miserere_1_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=vXeGJgI1YhY&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=126
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 40_Miserere_2_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=feWt88HF5sM&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=127
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 40_Miserere_3_ob.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=YtVlgU_NnP4&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=128
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 40_Miserere_4_cl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=IP3pTaO0hhI&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=129
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 40_Miserere_5_bn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=P29uaY2pxVE&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=130
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 41_Miserere_1_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=rqLTkMr2E-4&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=131
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 41_Miserere_2_fl.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=e40q0GOxHHs&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=132
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 41_Miserere_3_ob.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=pzXxzGhIu9s&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=133
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 41_Miserere_4_sax.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=1r_tFFpfFP4&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=134
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 41_Miserere_5_bn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=eidzJznfxjU&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=135
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 42_Arioso_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=tSMaynDTRqY&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=136
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 42_Arioso_4_tbn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=Awv_gSVePuw&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=137
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 42_Arioso_2_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=4fvdaplleH8&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=138
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 42_Arioso_3_hn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=xXTdnUguWnQ&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=139
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 42_Arioso_5_tba.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=C37zVQtyLDs&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=140
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 43_Chorale_1_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=qBzr5cz_YmE&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=141
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 43_Chorale_2_tpt.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=BBVcQjtiJ3o&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=142
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 43_Chorale_3_hn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=tzYWOHnKiig&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=143
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 43_Chorale_4_tbn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=89zMH857I9E&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=144
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 43_Chorale_5_tba.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=whHOVi4AXRs&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=145
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 44_K515_1_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=V8nWTsyZdL4&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=146
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 44_K515_2_vn.mp4'

# %%
from pytube import YouTube
link=input("URL:")
yt=YouTube(link)
yt.streams.filter(only_audio=True).first().download()
# Out:
# URL:https://www.youtube.com/watch?v=iwI5VskzgAI&list=PLSf9SKAnNHL0Jsvi_SzHYEWF4qoJaodYD&index=147
# '/content/drive/MyDrive/github/DL-Instrument-Identification/Performance_datasets/URMP Dataset Annotation -- 44_K515_3_va.mp4'
